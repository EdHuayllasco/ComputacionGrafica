# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# Ejercicio 1. Cree un arreglo de 5x5 donde los números sean aleatorios del 1 al 10

# %%
arr = np.random.randint(1,11,25)
arr = arr.reshape(5,5)
arr
# Out:
# array([[ 2,  6,  4,  5,  4],
#        [ 3,  2,  8,  7,  1],
#        [ 2, 10,  8,  4, 10],
#        [ 1,  1,  1,  6, 10],
#        [ 8,  7, 10,  1,  3]])

# %% [markdown]
# Ejercicio 2. Muestre solo el canal azul de la figura

# %%
pic = Image.open('eiffeltower.jpg')
pic_arr = np.asarray(pic)
plt.imshow(pic_arr)

# %%
pic_blue = pic_arr.copy()
pic_blue[:,:,0] = 0
pic_blue[:,:,1] = 0
plt.imshow(pic_blue)

# %% [markdown]
# Ejercicio 3. Cambie la imagen a escala de grises

# %%
plt.imshow(pic_arr[:,:,2], cmap='gray')

# %% [markdown]
# Ejercicio 4. Guarde una nueva imagen que contenga solo los canales rojo y verde

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img_cv = cv2.imread('eiffeltower.jpg') # trabaja con canales BGR
img_rg = img_cv.copy()

img_rg[:,:,0] = 0  # aqui se anula el canal Blue
cv2.imwrite('eiffelrg.png',img_rg)

cv2_imshow(img_rg) # visualizacion del resultado en rojo y verde
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1000 at 0x7FCB614BEC50>

# %% [markdown]
# Ejercicio 5. Guarde una nueva imagen que muestre la imagen en escala de grises

# %%
img_gris = cv2.imread('eiffeltower.jpg',0) # el segundo parámetro en cero anula los colores
cv2.imwrite('eiffelgris.png',img_gris)

cv2_imshow(img_gris) # visualización del resultado
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1600x1000 at 0x7FCB614D6E90>
